# %% [markdown]
# <a href="https://colab.research.google.com/github/GiangAnhTuan-20146450/Bai-Tap-AI/blob/main/AI_W9_31_03_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import mnist
(train_images,train_labels),(test_images,test_labels)=mnist.load_data()

test_images.shape
# Out:
# (10000, 28, 28)

# %%
X = test_images
Y = test_labels

# %%
import matplotlib.pyplot as plt
digit = train_images[350]
plt.imshow(digit,cmap=plt.cm.binary)
plt.show()
print('So nay la',train_labels[350])
# Out:
# So nay la 9

# %%
for i in range(25):
  plt.subplot(5,5,i+1)
  plt.tight_layout()
  plt.imshow(train_images[i],cmap='gray',interpolation='none')
  plt.title('So:{}'.format(train_labels[i]))
  plt.xticks([])
  plt.yticks([])

# %%
from keras.models import Sequential
from keras.layers import Dense
model = Sequential()
model.add(Dense(512,activation = 'relu',input_shape=(784,)))
model.add(Dense(10,activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 512)               401920
#
#  dense_1 (Dense)             (None, 10)                5130
#
# ...
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_images = train_images.reshape(60000,28*28)

# %%
train_images = train_images.astype('float32')/255

# %%
test_images = test_images.reshape(10000,28*28)

# %%
test_images = test_images.astype('float32')/255

# %%
train_images.shape
# Out:
# (60000, 784)

# %%
test_images.shape
# Out:
# (10000, 784)

# %%
from keras.utils import to_categorical
train_labels = to_categorical(train_labels,10)
test_labels = to_categorical(test_labels,10)

# %%
train_labels.shape
# Out:
# (60000, 10)

# %%
test_labels.shape
# Out:
# (10000, 10)

# %%
model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(train_images,train_labels,epochs=10,batch_size=128)
test_loss,test_acc=model.evaluate(test_images,test_labels)
print('Mat mat:',test_loss)
print('Do chinh xac:',test_acc)
# Out:
# Epoch 1/10
# 469/469 [==============================] - 5s 10ms/step - loss: 0.1419 - accuracy: 0.9601
# Epoch 2/10
# 469/469 [==============================] - 5s 12ms/step - loss: 0.1407 - accuracy: 0.9604
# Epoch 3/10
# 469/469 [==============================] - 5s 11ms/step - loss: 0.1390 - accuracy: 0.9606
# Epoch 4/10
# 469/469 [==============================] - 5s 10ms/step - loss: 0.1376 - accuracy: 0.9611
# Epoch 5/10
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1360 - accuracy: 0.9615
# Epoch 6/10
# 469/469 [==============================] - 5s 10ms/step - loss: 0.1344 - accuracy: 0.9618
# Epoch 7/10
# 469/469 [==============================] - 5s 12ms/step - loss: 0.1332 - accuracy: 0.9623
# Epoch 8/10
# 469/469 [==============================] - 5s 11ms/step - loss: 0.1320 - accuracy: 0.9630
# Epoch 9/10
# 469/469 [==============================] - 5s 10ms/step - loss: 0.1301 - accuracy: 0.9635
# Epoch 10/10
# ...

# %%
img = X[741]
plt.imshow(img)
plt.show()
print(Y[741])
# Out:
# 2

# %%
X_pred=X[741].reshape(1,28*28)

# %%
X_pred = X_pred.astype('float32')/255

# %%
import numpy as np
np.argmax(model.predict(X_pred),axis=-1)
# Out:
# 1/1 [==============================] - 0s 27ms/step
# array([2])

# %%
import keras
from keras.datasets import cifar10
(x_train,y_train),(x_test,y_test)= cifar10.load_data()

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
y_train.shape
# Out:
# (50000, 1)

# %%
x_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
X = x_test
Y = y_test

# %%
import matplotlib.pyplot as plt
digit = x_train[350]
plt.imshow(digit,cmap=plt.cm.binary)
plt.show()
print('Hinh nay la',y_train[350])
# Out:
# Hinh nay la [6]

# %%
for i in range(25):
  plt.subplot(5,5,i+1)
  plt.tight_layout()
  plt.imshow(x_train[i],cmap='gray',interpolation='none')
  plt.title('Hinh:{}'.format(y_train[i]))
  plt.xticks([])
  plt.yticks([])

# %%
from keras.models import Sequential
from keras.layers import Dense
model = Sequential()
model.add(Dense(1000,activation = 'relu',input_shape=(3072,)))
model.add(Dense(10,activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 1000)              3073000
#
#  dense_7 (Dense)             (None, 10)                10010
#
# ...
# Total params: 3,083,010
# Trainable params: 3,083,010
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_train = x_train.reshape(50000,32*32*3)
x_train = x_train.astype('float32')/255
x_test = x_test.reshape(10000,32*32*3)
x_test = x_test.astype('float32')/255

# %%
x_train.shape
# Out:
# (50000, 3072)

# %%
x_test.shape
# Out:
# (10000, 3072)

# %%
from keras.utils import to_categorical
y_train = to_categorical(y_train,10)
y_test = to_categorical(y_test,10)

# %%
y_train.shape
# Out:
# (50000, 10)

# %%
y_test.shape
# Out:
# (10000, 10)

# %%
model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(x_train,y_train,epochs=10,batch_size=128)
test_loss,test_acc=model.evaluate(x_test,y_test)
print('Mat mat:',test_loss)
print('Do chinh xac:',test_acc)
# Out:
# Epoch 1/10
# 391/391 [==============================] - 25s 64ms/step - loss: 1.4615 - accuracy: 0.4868
# Epoch 2/10
# 391/391 [==============================] - 25s 63ms/step - loss: 1.4408 - accuracy: 0.4921
# Epoch 3/10
# 391/391 [==============================] - 25s 64ms/step - loss: 1.4277 - accuracy: 0.4961
# Epoch 4/10
# 391/391 [==============================] - 25s 63ms/step - loss: 1.4066 - accuracy: 0.5043
# Epoch 5/10
# 391/391 [==============================] - 25s 63ms/step - loss: 1.3922 - accuracy: 0.5091
# Epoch 6/10
# 391/391 [==============================] - 26s 66ms/step - loss: 1.3803 - accuracy: 0.5162
# Epoch 7/10
# 391/391 [==============================] - 24s 62ms/step - loss: 1.3638 - accuracy: 0.5196
# Epoch 8/10
# 391/391 [==============================] - 25s 63ms/step - loss: 1.3529 - accuracy: 0.5241
# Epoch 9/10
# 391/391 [==============================] - 25s 64ms/step - loss: 1.3439 - accuracy: 0.5267
# Epoch 10/10
# ...

# %%
img = plt.imread('cho.jpg')
plt.imshow(img)
plt.show()

# %%
from keras.utils import load_img,img_to_array
img = load_img('cho.jpg',target_size=(32,32))
plt.imshow(img)
img=img_to_array(img)
img=img.reshape(1,32*32*3)
img=img.astype('float32')
img=img/255
np.argmax(model.predict(img),axis=-1)
# Out:
# 1/1 [==============================] - 0s 128ms/step
# array([2])
