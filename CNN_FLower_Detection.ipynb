# %% [markdown]
# <a href="https://colab.research.google.com/github/GiangAnhTuan-20146450/Bai-Tap-AI/blob/main/CNN_FLower_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import library
import pandas as pd
import numpy as np
from os import listdir
from numpy import asanyarray, save
from keras.utils import load_img, img_to_array
from numpy.core.multiarray import asarray
from google.colab import drive
from keras.utils import to_categorical
from PIL import Image
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
folder = '/content/drive/MyDrive/Flowers_ML/Flowers/flowertrain/'
photos, labels = list(), list()
for file in listdir(folder):
  output = 0.0
  if file.startswith('daisy'):
    output = 1.0
  if file.startswith('dandelion'):
    output = 2.0
  if file.startswith('rose'):
    output = 3.0
  if file.startswith('sunflower'):
    output = 4.0 
  if file.startswith('tulip'):
    output = 5.0
  photo = load_img(folder+file, target_size = (60,60))
  photo = img_to_array(photo)
  photos.append(photo)
  labels.append(output)
photos = asarray(photos)
labels = asarray(labels)
print(photos.shape, labels.shape)
# Out:
# (4317, 60, 60, 3) (4317,)

# %%
# Save data 
save('/content/drive/MyDrive/Flowers_ML/flower_photos.npy', photos)
save('/content/drive/MyDrive/Flowers_ML/flower_labels.npy', labels)

# %%
# Load data
photos = np.load('/content/drive/MyDrive/Flowers_ML/flower_photos.npy')
labels = np.load('/content/drive/MyDrive/Flowers_ML/flower_labels.npy')

# %%
X_train, X_test, y_train, y_test = train_test_split(photos, labels, test_size=0.1, random_state=3)

# %%
X_train.shape
# Out:
# (3885, 60, 60, 3)

# %%
y_train.shape
# Out:
# (3885,)

# %%
X_test.shape
# Out:
# (432, 60, 60, 3)

# %%
y_test.shape
# Out:
# (432,)

# %%
# Standardized data
X_train = X_train.astype('float32')/255
y_train = to_categorical(y_train, 6) 

X_test = X_test.astype('float32')/255
y_test = to_categorical(y_test, 6)

# %%
y_train.shape
# Out:
# (3885, 6)

# %%
y_test.shape
# Out:
# (432, 6)

# %%
# Import library
from keras.layers.attention.multi_head_attention import activation
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, normalization, LeakyReLU
from keras.optimizers import Adam
from keras.losses import categorical_crossentropy

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(60, 60, 3), padding='same'))
model.add(Dropout(0.5))
model.add(MaxPooling2D((2, 2), padding='same'))

model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(Dropout(0.5))
model.add(MaxPooling2D((2, 2), padding='same'))

model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(Dropout(0.5))
model.add(MaxPooling2D((2, 2), padding='same'))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(6, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 60, 60, 32)        896
#
#  dropout (Dropout)           (None, 60, 60, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 30, 30, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 64)        18496
#
#  dropout_1 (Dropout)         (None, 30, 30, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 15, 15, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 128)       73856
#
#  dropout_2 (Dropout)         (None, 15, 15, 128)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 128)               1048704
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 6)                 774
#
# ...

# %%
# Compile and Train model
model.compile(loss = categorical_crossentropy,
              optimizer = Adam(),
              metrics = ['accuracy'])
train = model.fit(X_train, y_train, batch_size = 100, epochs = 45, verbose = 1)
# Out:
# Epoch 1/45
# 39/39 [==============================] - 10s 27ms/step - loss: 1.6340 - accuracy: 0.2767
# Epoch 2/45
# 39/39 [==============================] - 1s 20ms/step - loss: 1.3040 - accuracy: 0.4486
# Epoch 3/45
# 39/39 [==============================] - 1s 20ms/step - loss: 1.1851 - accuracy: 0.5202
# Epoch 4/45
# 39/39 [==============================] - 1s 20ms/step - loss: 1.1359 - accuracy: 0.5421
# Epoch 5/45
# 39/39 [==============================] - 1s 19ms/step - loss: 1.0606 - accuracy: 0.5802
# Epoch 6/45
# 39/39 [==============================] - 1s 19ms/step - loss: 0.9928 - accuracy: 0.6113
# Epoch 7/45
# 39/39 [==============================] - 1s 20ms/step - loss: 0.9492 - accuracy: 0.6304
# Epoch 8/45
# 39/39 [==============================] - 1s 21ms/step - loss: 0.9277 - accuracy: 0.6373
# Epoch 9/45
# 39/39 [==============================] - 1s 21ms/step - loss: 0.8619 - accuracy: 0.6641
# Epoch 10/45
# ...

# %%
# Save model
model.save('/content/drive/MyDrive/Flowers_ML/Flowers_Train_Model.h5')

# %%
test = model.evaluate(X_test, y_test, verbose=0)
print('Test loss: ', test[0])
print('Test accuracy', test[1])
accuracy=train.history['accuracy']
loss=train.history['loss']
epochs=range(len(accuracy))
plt.plot(epochs, accuracy, 'bo', label='Training accuracy')
plt.plot(epochs, loss, 'b', label='Training loss')
plt.legend()
plt.show()
# Out:
# Test loss:  0.8495075106620789
# Test accuracy 0.6898148059844971

# %%
import matplotlib.pyplot as plt
from keras.utils import load_img
from keras.utils.image_utils import img_to_array
import numpy as np
vat = {1: 'daisy',2:'dandelion', 3:'rose', 4:'sunflower',5:'tulip'}
img = load_img("/content/Dandeliontest.jpg",target_size=(60,60))
plt.imshow(img)
img = img_to_array(img)
img=img.reshape(1,60,60,3)
img = img.astype('float32')
img =img/255
result  = np.argmax(model.predict(img),axis=1)
vat[result[0]]
# Out:
# 1/1 [==============================] - 0s 20ms/step
# 'dandelion'

# %%
import matplotlib.pyplot as plt
from keras.utils import load_img
from keras.utils.image_utils import img_to_array
import numpy as np
vat = {1: 'daisy',2:'dandelion', 3:'rose', 4:'sunflower',5:'tulip'}
img = load_img("/content/Rosetest.jpg",target_size=(60,60))
plt.imshow(img)
img = img_to_array(img)
img=img.reshape(1,60,60,3)
img = img.astype('float32')
img =img/255
result  = np.argmax(model.predict(img),axis=1)
vat[result[0]]
# Out:
# 1/1 [==============================] - 0s 21ms/step
# 'rose'

# %%
import matplotlib.pyplot as plt
from keras.utils import load_img
from keras.utils.image_utils import img_to_array
import numpy as np
vat = {1: 'daisy',2:'dandelion', 3:'rose', 4:'sunflower',5:'tulip'}
img = load_img("/content/Sunflowertest.jpg",target_size=(60,60))
plt.imshow(img)
img = img_to_array(img)
img=img.reshape(1,60,60,3)
img = img.astype('float32')
img =img/255
result  = np.argmax(model.predict(img),axis=1)
vat[result[0]]
# Out:
# 1/1 [==============================] - 0s 75ms/step
# 'sunflower'

# %%
import matplotlib.pyplot as plt
from keras.utils import load_img
from keras.utils.image_utils import img_to_array
import numpy as np
vat = {1: 'daisy',2:'dandelion', 3:'rose', 4:'sunflower',5:'tulip'}
img = load_img("/content/Tuliptest.jpg",target_size=(60,60))
plt.imshow(img)
img = img_to_array(img)
img=img.reshape(1,60,60,3)
img = img.astype('float32')
img =img/255
result  = np.argmax(model.predict(img),axis=1)
vat[result[0]]
# Out:
# 1/1 [==============================] - 0s 19ms/step
# 'tulip'
